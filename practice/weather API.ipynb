# %%
from urllib import request
import json

# encoding = "utf-8-sig" 가 있어야 유니코드로 해당 파일을 제대로 읽어냄
json_data=open(r"C:\Users\my\Desktop\city.list.json\city.list.json", encoding = "utf-8-sig").read() 
data = json.loads(json_data)

print("json file data's type is", type(data))

korea_information = []
for i in range(len(data)):
    if data[i]["country"] == "KR":
        korea_information.append(data[i])

# for i in range(len(korea_information)):
#     print(korea_information[i]["name"],korea_information[i]["id"] )   
    
    
korea_cities_dict = {}

for i in range(len(korea_information)):
    korea_cities_dict[korea_information[i]["name"]] = korea_information[i]["id"]

print(korea_cities_dict)
# korea_cities_name = []

# for i in range(len(korea_information)):
#     korea_cities_name.append(korea_information[i]["name"])

# kore_cities_id = []

# for i in range(len(korea_information)):
#     kore_cities_id.append(korea_information[i]["id"])
# Out:
# json file data's type is <class 'list'>
# ...

# %%
korea_cities_name
# Out:
# ['Neietsu',
#  'Reiko',
#  'Yeoju',
#  'Yanggu',
#  'Mungyeong',
#  'Kurye',
#  'Cheongsong gun',
#  'Chinchon',
#  'Hwawon',
#  'Ch’ungch’ŏng-bukto',
#  '괴내',
#  'Tangp’yŏng',
#  'Umulmok',
#  'Myŏngwŏli-ri',
#  'Namhyang-dong',
#  'Kinho',
#  'Sup’yŏng-dong',
#  'P’ungnap-tong',
#  'Hamyang',
#  'Enjitsu',
#  'yeoncheongun',
#  'Yangpyong',
#  'Yangju',
#  'Wanju',
#  'Waegwan',
#  'Vijongbu',
#  'Taesal-li',
#  'Taejŏn-gwangyŏksi',
#  'Puan',
#  'Asan',
#  'Munsan',
#  'Kwangju',
#  'Kuri',
#  'Kunwi',
#  'Kinzan',
#  'Kumi',
#  'Kyosai',
#  'Gimcheon',
#  'Gapyeong',
#  'Hwaseong',
#  'Hwacheon',
#  'Hongsung',
#  'Hongchon',
#  'jin-angun',
#  'Changsu',
#  'Yonmu',
#  'Tonghae',
#  'Pubal',
#  'Seongnam',
#  'Hwado',
#  'Naeso',
#  'Changnyeong',
#  'Unsal-li',
#  'Kangp’o-ri',
#  'Taian',
#  'Teisen',
#  'Kanhei',
#  'Heung-hai',
#  'Eisen',
#  'Taisen-ri',
#  'Jenzan',
#  'Songwon',
#  'Fuyo',
#  'Beolgyo',
#  'Kosong',
#  'Kijang',
#  'Imsil',
#  'Hayang',
#  'Gaigeturi',
# ...

# %%
kore_cities_id
# Out:
# [1832257,
#  1832501,
#  1832743,
#  1832909,
#  1840886,
#  1841976,
#  1845519,
#  1846095,
#  1925943,
#  1845106,
#  6802827,
#  1890085,
#  1833702,
#  6367618,
#  6573030,
#  1842936,
#  6800892,
#  6800397,
#  1844533,
#  1832215,
#  1832697,
#  1832830,
#  1832847,
#  1833466,
#  1833514,
#  1833788,
#  1835096,
#  1835224,
#  1838722,
#  1839726,
#  1840862,
#  1841810,
#  1841988,
#  1842016,
#  1842153,
#  1842225,
#  1842754,
#  1842944,
#  1843082,
#  1843847,
#  1844045,
#  1844174,
#  1844191,
#  1846114,
#  1846355,
#  1886598,
#  1892823,
#  1896953,
#  1897000,
#  1897118,
#  1925936,
#  6903078,
#  1833581,
#  1884249,
#  1835518,
#  1846278,
#  1844539,
#  1832015,
#  1832617,
#  1835447,
#  1835967,
#  1836208,
#  1838508,
#  1839011,
#  1840179,
#  1842966,
#  1843585,
#  1844308,
#  1847050,
#  1882056,
#  1912205,
#  6395804,
#  1835841,
#  1902028,
#  1846430,
#  6901961,
#  6901967,
#  1841597,
#  6890843,
#  1845105,
#  1846589,
#  6887688,
#  6891973,
# ...

# %%
import urllib.request, json

# 해당 url에 api가 담겨있고, 이 api의 확장자는 json이다.(받을 api의 확장자는 요청 받을 때 선택하면 됨)
f1=urllib.request.urlopen("http://api.openweathermap.org/data/2.5/weather?id=1843564&APPID=2ae88b3ec4b4537d15165fca377a3ca9")
print(type(f1))
s=json.loads(f1.read())
print(s)
print("*"*50)
print(type(s))
# f2=open("d:/city.list.json", encoding='utf-8-sig').read()
# cities = json.loads(f2)
# print(len(cities))

# for city in cities:
#     if city['country'] == 'KR':
#         print(city['name'], city['id'])

# # print(city[1])
# # print(city[1]['id'] )
# # print(s)
# Out:
# <class 'http.client.HTTPResponse'>
# {'coord': {'lon': 126.73, 'lat': 37.45}, 'weather': [{'id': 721, 'main': 'Haze', 'description': 'haze', 'icon': '50d'}], 'base': 'stations', 'main': {'temp': 297.38, 'pressure': 1010, 'humidity': 69, 'temp_min': 295.15, 'temp_max': 299.15}, 'visibility': 10000, 'wind': {'speed': 3.6, 'deg': 240}, 'clouds': {'all': 1}, 'dt': 1559643647, 'sys': {'type': 1, 'id': 5504, 'message': 0.0047, 'country': 'KR', 'sunrise': 1559592792, 'sunset': 1559645381}, 'timezone': 32400, 'id': 1843564, 'name': 'Incheon', 'cod': 200}
# **************************************************
# <class 'dict'>
